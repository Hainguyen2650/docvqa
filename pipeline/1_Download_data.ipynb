# %% [markdown]
# ## Import thư viện và khởi tạo

# %%
import sys
sys.path.insert(0, '..')
import pathlib
PROJECT_ROOT = pathlib.Path().resolve().parents[1]
sys.path.append(str(PROJECT_ROOT))
import matplotlib.pyplot as plt
from PIL import Image
from src.Datasets.data_downloader import DocVQADownloader
# Khởi tạo downloader với cấu hình mặc định
downloader = DocVQADownloader(
    repo_id="lmms-lab/DocVQA",
    local_dir="../dataset",
    raw_folder="../dataset/DocVQA_raw",
    images_folder="../dataset/DocVQA_Images",
    labels_folder="../dataset/DocVQA_Labels"
)

print("Đã khởi tạo DocVQADownloader")
# Out:
# Đã khởi tạo DocVQADownloader

# %% [markdown]
# ## Bước 1: Tải dataset từ HuggingFace

# %%
dataset_path = downloader.download_from_huggingface()
# Out:
# Đang tải dataset từ HuggingFace...
# e:\Py venv\main\.venv\lib\site-packages\huggingface_hub\utils\_validators.py:186: UserWarning: The `resume_download` argument is deprecated and ignored in `snapshot_download`. Downloads always resume whenever possible.
#   warnings.warn(
# e:\Py venv\main\.venv\lib\site-packages\huggingface_hub\utils\_validators.py:202: UserWarning: The `local_dir_use_symlinks` argument is deprecated and ignored in `snapshot_download`. Downloading to a local directory does not use symlinks anymore.
#   warnings.warn(
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 24 files:   0%|          | 0/24 [00:00<?, ?it/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.

# %% [markdown]
# ## Bước 2: Trích xuất ảnh từ file parquet

# %%
downloader.extract_images_from_parquet()
# Out:
# Raw folder: ../dataset/DocVQA_raw
# Tìm thấy 24 file parquet.
# Đang xử lý: test-00000-of-00006.parquet...
# Extracting test: 100%|██████████| 865/865 [01:34<00:00,  9.17it/s]
# Đang xử lý: test-00001-of-00006.parquet...
# Extracting test: 100%|██████████| 865/865 [01:45<00:00,  8.17it/s]
# Đang xử lý: test-00002-of-00006.parquet...
# Extracting test: 100%|██████████| 865/865 [02:13<00:00,  6.50it/s]
# Đang xử lý: test-00003-of-00006.parquet...
# Extracting test: 100%|██████████| 865/865 [02:18<00:00,  6.25it/s]
# Đang xử lý: test-00004-of-00006.parquet...
# Extracting test: 100%|██████████| 864/864 [02:12<00:00,  6.53it/s]
# Đang xử lý: test-00005-of-00006.parquet...
# Extracting test: 100%|██████████| 864/864 [02:38<00:00,  5.46it/s]
# Đang xử lý: train-00000-of-00012.parquet...
# Extracting train: 100%|██████████| 3289/3289 [06:54<00:00,  7.93it/s]
# Đang xử lý: train-00001-of-00012.parquet...
# Extracting train: 100%|██████████| 3289/3289 [02:45<00:00, 19.89it/s]
# Đang xử lý: train-00002-of-00012.parquet...
# Extracting train: 100%|██████████| 3289/3289 [03:36<00:00, 15.16it/s]
# Đang xử lý: train-00003-of-00012.parquet...
# Extracting train: 100%|██████████| 3289/3289 [05:39<00:00,  9.68it/s]
# Đang xử lý: train-00004-of-00012.parquet...
# Extracting train: 100%|██████████| 3289/3289 [11:53<00:00,  4.61it/s]
# Đang xử lý: train-00005-of-00012.parquet...
# Extracting train: 100%|██████████| 3289/3289 [11:00<00:00,  4.98it/s]
# Đang xử lý: train-00006-of-00012.parquet...
# Extracting train: 100%|██████████| 3289/3289 [10:47<00:00,  5.08it/s]
# Đang xử lý: train-00007-of-00012.parquet...
# Extracting train: 100%|██████████| 3288/3288 [14:12<00:00,  3.86it/s]
# Đang xử lý: train-00008-of-00012.parquet...
# Extracting train: 100%|██████████| 3288/3288 [06:10<00:00,  8.86it/s]
# Đang xử lý: train-00009-of-00012.parquet...
# Extracting train: 100%|██████████| 3288/3288 [09:37<00:00,  5.69it/s]
# Đang xử lý: train-00010-of-00012.parquet...
# Extracting train: 100%|██████████| 3288/3288 [04:16<00:00, 12.83it/s]
# Đang xử lý: train-00011-of-00012.parquet...
# Extracting train: 100%|██████████| 3288/3288 [09:17<00:00,  5.90it/s]
# Đang xử lý: validation-00000-of-00006.parquet...
# Extracting validation: 100%|██████████| 892/892 [01:29<00:00,  9.95it/s]
# Đang xử lý: validation-00001-of-00006.parquet...
# Extracting validation: 100%|██████████| 892/892 [01:44<00:00,  8.52it/s]
# Đang xử lý: validation-00002-of-00006.parquet...
# Extracting validation: 100%|██████████| 892/892 [02:10<00:00,  6.83it/s]
# Đang xử lý: validation-00003-of-00006.parquet...
# Extracting validation: 100%|██████████| 891/891 [01:53<00:00,  7.82it/s]
# Đang xử lý: validation-00004-of-00006.parquet...
# Extracting validation: 100%|██████████| 891/891 [02:15<00:00,  6.58it/s]
# Đang xử lý: validation-00005-of-00006.parquet...
# Extracting validation: 100%|██████████| 891/891 [02:19<00:00,  6.37it/s]
# Hoàn tất quá trình trích xuất ảnh!

# %% [markdown]
# ## Bước 3: Tạo file CSV labels

# %%
downloader.generate_labels_csv()
# Out:
# Đã tìm thấy 3 file labels CSV trong ../dataset/DocVQA_Labels:
#   - test_labels.csv
#   - train_labels.csv
#   - validation_labels.csv
# Bỏ qua tạo labels. Để tạo lại, dùng: generate_labels_csv(force_generate=True)

# %% [markdown]
# ## Thống kê Dataset

# %%
# Xem thống kê dataset
stats = downloader.get_dataset_stats()

print("="*50)
print("THỐNG KÊ DATASET DocVQA")
print("="*50)
for subset, count in stats.items():
    print(f"  {subset:15}: {count:,} ảnh")
print("="*50)
print(f"  {'TỔNG':15}: {sum(stats.values()):,} ảnh")
# Out:
# ==================================================
# THỐNG KÊ DATASET DocVQA
# ==================================================
#   train          : 39,463 ảnh
#   test           : 5,188 ảnh
#   validation     : 5,349 ảnh
# ==================================================
#   TỔNG           : 50,000 ảnh

# %% [markdown]
# ## Hiển thị ảnh mẫu

# %%
# Lấy ảnh mẫu từ tập train
sample_images = downloader.get_sample_images(subset="train", n_samples=6)

if sample_images:
    fig, axes = plt.subplots(2, 3, figsize=(15, 10))
    axes = axes.flatten()
    
    for idx, img_path in enumerate(sample_images):
        if idx < len(axes):
            img = Image.open(img_path)
            axes[idx].imshow(img)
            axes[idx].set_title(f"Sample {idx+1}", fontsize=12)
            axes[idx].axis('off')
    
    # Ẩn các subplot trống
    for idx in range(len(sample_images), len(axes)):
        axes[idx].axis('off')
    
    plt.suptitle("Ảnh mẫu từ tập Train - DocVQA", fontsize=16)
    plt.tight_layout()
    plt.show()
else:
    print("Không tìm thấy ảnh mẫu. Hãy chạy các bước trước đó.")

# %% [markdown]
# ## Xem nội dung file Labels CSV

# %%
import pandas as pd
import os

labels_path = "../dataset/DocVQA_Labels/train_labels.csv"

if os.path.exists(labels_path):
    df = pd.read_csv(labels_path)
    print(f"Số dòng: {len(df)}")
    print(f"\nCác cột: {df.columns.tolist()}")
    print("\n5 dòng đầu tiên:")
    display(df.head())
else:
    print(f"File {labels_path} chưa tồn tại. Hãy chạy bước tạo labels trước.")
# Out:
# Số dòng: 39463
#
# Các cột: ['questionId', 'question', 'docId', 'image_filename', 'image_path', 'answers']
#
# 5 dòng đầu tiên:
#    questionId                                           question  docId  \
# 0         337         what is the date mentioned in this letter?    279
# 1         338  what is the contact person name mentioned in l...    279
# 2         339            Which corporation's letterhead is this?    280
# 3         340                      Who is in  cc in this letter?    280
# 4         341               what is the subject of  this letter?    280
#
#   image_filename     image_path  \
# 0        337.png  train\337.png
# 1        338.png  train\338.png
# 2        339.png  train\339.png
# 3        340.png  train\340.png
# 4        341.png  train\341.png
#
#                                           answers
# 0                                      ['1/8/93']
# 1                       ['P. Carter' 'p. carter']
# 2      ['Brown & Williamson Tobacco Corporation']
# 3                                  ['T.F. Riehl']
# 4  ['Review of existing Brainstorming Ideas/483']
